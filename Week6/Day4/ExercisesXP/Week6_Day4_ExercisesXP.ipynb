# %% [markdown]
# # Week 6 Day 4 — Exercises XP
# Advanced Excel Techniques: loading each exercise workbook with pandas to review its contents.

# %%
import pandas as pd
from pathlib import Path

folder = Path('.')
files = {
    'Ex1': 'Ex1_BeetleLength.xlsx',
    'Ex2': 'Ex2_HolidaysPivot.xlsx',
    'Ex3': 'Ex3_OscarNominations.xlsx',
}

# %% [markdown]
# ## Ex1 — Beetle Length (IF formula)

# %%
ex1_sheets = pd.read_excel(folder / files['Ex1'], sheet_name=None)
for name, df in ex1_sheets.items():
    print(f'--- {name} ---')
    display(df)

# %% [markdown]
# ## Ex2 — Holidays (Pivot Table)

# %%
ex2_sheets = pd.read_excel(folder / files['Ex2'], sheet_name=None)
for name, df in ex2_sheets.items():
    print(f'--- {name} ---')
    display(df)

# %% [markdown]
# ## Ex3 — Oscar Nominations / Movies (Pivot Chart)

# %%
ex3_sheets = pd.read_excel(folder / files['Ex3'], sheet_name=None)
for name, df in ex3_sheets.items():
    print(f'--- {name} ---')
    display(df)
